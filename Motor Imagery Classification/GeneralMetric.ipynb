# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from itertools import combinations

from scipy.signal import welch, butter, filtfilt, detrend
from scipy.stats import skew, kurtosis, entropy, wasserstein_distance, ks_2samp
from tqdm.auto import tqdm


# ============================================================
# CONFIG
# ============================================================

FS = 250

LEFT_LABEL = 1
RIGHT_LABEL = 2

CLASS_NAMES = {
    LEFT_LABEL: "left",
    RIGHT_LABEL: "right"
}

# Name them however you want.
# These names appear in the matrices and plots.
DATASETS = {
    "Arnav": "Datasets/Main.npz",
    "Fauzaan": "Datasets/Main1.npz",
    "Devin": "Datasets/Main2.npz",
    "Erim" : "Datasets/Main3.npz",
}

BAD_CHANNELS = [0, 1, 2, 4, 6, 7]

FEATURE_DATABASE_PATH = "Datasets/eeg_feature_database.csv"

SAVE_PLOTS = False

LEFT_HEATMAP_PATH = "Datasets/left_similarity_heatmap.png"
RIGHT_HEATMAP_PATH = "Datasets/right_similarity_heatmap.png"

LEFT_BARPLOT_PATH = "Datasets/left_average_similarity.png"
RIGHT_BARPLOT_PATH = "Datasets/right_average_similarity.png"

# If None, remaining channels after deletion become ch0, ch1, ch2...
CHANNEL_NAMES = None

# Speed switches
USE_SLOW_FEATURES = False
USE_CROSS_CHANNEL_BAND_FEATURES = True

# If True, rebuild features from raw npz files.
# If False, reload existing eeg_feature_database.csv.
REBUILD_FEATURE_DATABASE = True

# ============================================================
# IMPORTANT SCORE KNOB
# ============================================================
# Similarity is computed from the top K most similar features per person-pair/class.
# Example:
# TOP_K_FEATURES_FOR_SCORE = 10  -> only use top 10 most similar features
# TOP_K_FEATURES_FOR_SCORE = 50  -> use top 50
# TOP_K_FEATURES_FOR_SCORE = None -> use all features
TOP_K_FEATURES_FOR_SCORE = 75

EPS = 1e-12

BANDS = {
    "delta": (1, 4),
    "theta": (4, 8),
    "alpha": (8, 13),
    "low_beta": (13, 20),
    "high_beta": (20, 30),
    "beta": (13, 30),
    "gamma_low": (30, 45),
    "mu": (8, 13),
    "smr": (12, 15),
}


# ============================================================
# BASIC UTILS
# ============================================================

def safe(x):
    if np.isnan(x) or np.isinf(x):
        return 0.0
    return float(x)


def bandpass(sig, fs, low=1, high=45, order=4):
    nyq = fs / 2
    b, a = butter(order, [low / nyq, high / nyq], btype="band")
    return filtfilt(b, a, sig)


def bandpower(sig, fs, low, high):
    freqs, psd = welch(
        sig,
        fs=fs,
        nperseg=min(256, len(sig)),
        noverlap=min(128, len(sig) // 2)
    )

    mask = (freqs >= low) & (freqs <= high)

    if not np.any(mask):
        return 0.0

    return safe(np.trapezoid(psd[mask], freqs[mask]))


def spectral_entropy(sig, fs):
    freqs, psd = welch(
        sig,
        fs=fs,
        nperseg=min(256, len(sig)),
        noverlap=min(128, len(sig) // 2)
    )

    psd = psd + EPS
    psd_norm = psd / np.sum(psd)

    return safe(entropy(psd_norm) / np.log(len(psd_norm)))


def hjorth_params(sig):
    first_deriv = np.diff(sig)
    second_deriv = np.diff(first_deriv)

    var0 = np.var(sig) + EPS
    var1 = np.var(first_deriv) + EPS
    var2 = np.var(second_deriv) + EPS

    activity = var0
    mobility = np.sqrt(var1 / var0)
    complexity = np.sqrt(var2 / var1) / (mobility + EPS)

    return safe(activity), safe(mobility), safe(complexity)


def zero_crossing_rate(sig):
    return safe(np.mean(np.diff(np.signbit(sig))))


def line_length(sig):
    return safe(np.sum(np.abs(np.diff(sig))))


def rms(sig):
    return safe(np.sqrt(np.mean(sig ** 2)))


def mean_abs(sig):
    return safe(np.mean(np.abs(sig)))


def energy(sig):
    return safe(np.sum(sig ** 2))


def shannon_entropy_hist(sig, bins=30):
    hist, _ = np.histogram(sig, bins=bins, density=True)
    hist = hist + EPS
    hist = hist / np.sum(hist)
    return safe(entropy(hist))


def approximate_entropy(sig, m=2, r=None):
    sig = np.asarray(sig)

    if r is None:
        r = 0.2 * np.std(sig)

    N = len(sig)

    if N <= m + 1:
        return 0.0

    def _phi(mm):
        x = np.array([sig[i:i + mm] for i in range(N - mm + 1)])
        C = []

        for xi in x:
            dist = np.max(np.abs(x - xi), axis=1)
            C.append(np.mean(dist <= r))

        C = np.array(C) + EPS
        return np.mean(np.log(C))

    return safe(_phi(m) - _phi(m + 1))


def higuchi_fd(sig, kmax=8):
    sig = np.asarray(sig)
    N = len(sig)

    if N < kmax * 2:
        return 0.0

    L = []
    k_values = np.arange(1, kmax + 1)

    for k in k_values:
        Lk = []

        for m in range(k):
            idx = np.arange(m, N, k)

            if len(idx) < 2:
                continue

            dist = np.sum(np.abs(np.diff(sig[idx])))
            norm = (N - 1) / (len(idx) * k)
            Lk.append(dist * norm)

        L.append(np.mean(Lk) + EPS)

    L = np.array(L)
    coeffs = np.polyfit(np.log(1.0 / k_values), np.log(L), 1)

    return safe(coeffs[0])


def spectral_edge_frequency(sig, fs, edge=0.95):
    freqs, psd = welch(
        sig,
        fs=fs,
        nperseg=min(256, len(sig)),
        noverlap=min(128, len(sig) // 2)
    )

    cumulative = np.cumsum(psd)
    total = cumulative[-1] + EPS

    idx = np.searchsorted(cumulative, edge * total)

    if idx >= len(freqs):
        idx = len(freqs) - 1

    return safe(freqs[idx])


def dominant_frequency(sig, fs):
    freqs, psd = welch(
        sig,
        fs=fs,
        nperseg=min(256, len(sig)),
        noverlap=min(128, len(sig) // 2)
    )

    idx = np.argmax(psd)
    return safe(freqs[idx])


# ============================================================
# FEATURE EXTRACTION
# ============================================================

def extract_features_for_trial(trial, fs):
    """
    trial shape: (channels, samples)
    returns dict of features
    """

    features = {}

    n_channels = trial.shape[0]

    if CHANNEL_NAMES is None:
        ch_names = [f"ch{i}" for i in range(n_channels)]
    else:
        ch_names = CHANNEL_NAMES

    if len(ch_names) != n_channels:
        raise ValueError(
            f"CHANNEL_NAMES length {len(ch_names)} does not match number of channels {n_channels}"
        )

    filtered_trial = []

    for ch_idx, ch_name in enumerate(ch_names):
        sig_raw = trial[ch_idx].astype(float)

        sig = detrend(sig_raw)
        sig = bandpass(sig, fs, 1, 45)

        filtered_trial.append(sig)

        features[f"{ch_name}_mean"] = safe(np.mean(sig))
        features[f"{ch_name}_std"] = safe(np.std(sig))
        features[f"{ch_name}_var"] = safe(np.var(sig))
        features[f"{ch_name}_logvar"] = safe(np.log(np.var(sig) + EPS))
        features[f"{ch_name}_median"] = safe(np.median(sig))
        features[f"{ch_name}_min"] = safe(np.min(sig))
        features[f"{ch_name}_max"] = safe(np.max(sig))
        features[f"{ch_name}_ptp"] = safe(np.ptp(sig))
        features[f"{ch_name}_rms"] = rms(sig)
        features[f"{ch_name}_mean_abs"] = mean_abs(sig)
        features[f"{ch_name}_energy"] = energy(sig)
        features[f"{ch_name}_line_length"] = line_length(sig)
        features[f"{ch_name}_zcr"] = zero_crossing_rate(sig)
        features[f"{ch_name}_skew"] = safe(skew(sig))
        features[f"{ch_name}_kurtosis"] = safe(kurtosis(sig))
        features[f"{ch_name}_iqr"] = safe(np.percentile(sig, 75) - np.percentile(sig, 25))

        activity, mobility, complexity = hjorth_params(sig)

        features[f"{ch_name}_hjorth_activity"] = activity
        features[f"{ch_name}_hjorth_mobility"] = mobility
        features[f"{ch_name}_hjorth_complexity"] = complexity

        features[f"{ch_name}_spectral_entropy"] = spectral_entropy(sig, fs)
        features[f"{ch_name}_hist_entropy"] = shannon_entropy_hist(sig)

        if USE_SLOW_FEATURES:
            features[f"{ch_name}_approx_entropy"] = approximate_entropy(sig)
            features[f"{ch_name}_higuchi_fd"] = higuchi_fd(sig)

        total_power = bandpower(sig, fs, 1, 45) + EPS

        band_powers = {}

        for band_name, (low, high) in BANDS.items():
            bp = bandpower(sig, fs, low, high)
            band_powers[band_name] = bp + EPS

            features[f"{ch_name}_{band_name}_power"] = bp
            features[f"{ch_name}_{band_name}_rel_power"] = safe(bp / total_power)
            features[f"{ch_name}_{band_name}_log_power"] = safe(np.log(bp + EPS))

        features[f"{ch_name}_dominant_freq"] = dominant_frequency(sig, fs)
        features[f"{ch_name}_spectral_edge_95"] = spectral_edge_frequency(sig, fs, 0.95)
        features[f"{ch_name}_spectral_edge_90"] = spectral_edge_frequency(sig, fs, 0.90)

        alpha = band_powers["alpha"]
        beta = band_powers["beta"]
        theta = band_powers["theta"]
        delta = band_powers["delta"]
        gamma = band_powers["gamma_low"]
        mu = band_powers["mu"]
        smr = band_powers["smr"]

        features[f"{ch_name}_alpha_beta_ratio"] = safe(alpha / beta)
        features[f"{ch_name}_theta_beta_ratio"] = safe(theta / beta)
        features[f"{ch_name}_alpha_theta_ratio"] = safe(alpha / theta)
        features[f"{ch_name}_delta_theta_ratio"] = safe(delta / theta)
        features[f"{ch_name}_beta_alpha_ratio"] = safe(beta / alpha)
        features[f"{ch_name}_gamma_beta_ratio"] = safe(gamma / beta)
        features[f"{ch_name}_mu_beta_ratio"] = safe(mu / beta)
        features[f"{ch_name}_smr_beta_ratio"] = safe(smr / beta)

    filtered_trial = np.array(filtered_trial)

    if n_channels >= 2:
        for i in range(n_channels):
            for j in range(i + 1, n_channels):
                ch_i = ch_names[i]
                ch_j = ch_names[j]

                sig_i = filtered_trial[i]
                sig_j = filtered_trial[j]

                features[f"{ch_i}_{ch_j}_corr"] = safe(np.corrcoef(sig_i, sig_j)[0, 1])
                features[f"{ch_i}_{ch_j}_cov"] = safe(np.cov(sig_i, sig_j)[0, 1])

                if USE_CROSS_CHANNEL_BAND_FEATURES:
                    for band_name, (low, high) in BANDS.items():
                        bi = bandpass(sig_i, fs, low, high)
                        bj = bandpass(sig_j, fs, low, high)

                        features[f"{ch_i}_{ch_j}_{band_name}_corr"] = safe(
                            np.corrcoef(bi, bj)[0, 1]
                        )

                        features[f"{ch_i}_{ch_j}_{band_name}_cov"] = safe(
                            np.cov(bi, bj)[0, 1]
                        )

                        power_i = bandpower(sig_i, fs, low, high) + EPS
                        power_j = bandpower(sig_j, fs, low, high) + EPS

                        features[f"{ch_i}_{ch_j}_{band_name}_power_diff"] = safe(
                            power_i - power_j
                        )

                        features[f"{ch_i}_{ch_j}_{band_name}_power_abs_diff"] = safe(
                            abs(power_i - power_j)
                        )

                        features[f"{ch_i}_{ch_j}_{band_name}_power_ratio"] = safe(
                            power_i / power_j
                        )

                        features[f"{ch_i}_{ch_j}_{band_name}_log_power_ratio"] = safe(
                            np.log(power_i / power_j)
                        )

    return features


def extract_dataset_features(X, y, person_name, dataset_path):
    rows = []

    print(f"\n========== EXTRACTING FEATURES: {person_name} ==========")
    print(f"Dataset path: {dataset_path}")
    print(f"X shape: {X.shape}")
    print(f"Labels: {np.unique(y, return_counts=True)}")
    print(f"USE_SLOW_FEATURES: {USE_SLOW_FEATURES}")
    print(f"USE_CROSS_CHANNEL_BAND_FEATURES: {USE_CROSS_CHANNEL_BAND_FEATURES}")

    for trial_idx in tqdm(range(X.shape[0]), desc=f"{person_name} trials"):
        label = y[trial_idx]

        if label not in CLASS_NAMES:
            continue

        feats = extract_features_for_trial(X[trial_idx], FS)

        feats["person"] = person_name
        feats["dataset_path"] = dataset_path
        feats["trial_idx"] = trial_idx
        feats["label"] = label
        feats["class_name"] = CLASS_NAMES.get(label, str(label))

        rows.append(feats)

    df = pd.DataFrame(rows)

    print(f"Done: {person_name}")
    print(f"Feature table shape: {df.shape}")

    return df


# ============================================================
# FEATURE DATABASE
# ============================================================

def load_raw_dataset(path):
    data = np.load(path)

    X = data["X_raw"]
    y = data["y"]

    print("\nRaw loaded:", path)
    print("Before bad-channel deletion:", X.shape)

    X = np.delete(X, BAD_CHANNELS, axis=1)

    print("After bad-channel deletion:", X.shape)

    return X, y


def build_feature_database(datasets):
    all_dfs = []

    print("\n========== BUILDING FEATURE DATABASE ==========")

    os.makedirs(os.path.dirname(FEATURE_DATABASE_PATH), exist_ok=True)

    expected_channels = None

    for person_name, dataset_path in datasets.items():
        print(f"\nLoading {person_name}: {dataset_path}")

        X, y = load_raw_dataset(dataset_path)

        if expected_channels is None:
            expected_channels = X.shape[1]
        else:
            if X.shape[1] != expected_channels:
                raise ValueError(
                    f"Channel mismatch. Previous datasets had {expected_channels} channels, "
                    f"but {person_name} has {X.shape[1]} channels after deletion."
                )

        print(f"{person_name} labels:", np.unique(y, return_counts=True))

        df = extract_dataset_features(
            X=X,
            y=y,
            person_name=person_name,
            dataset_path=dataset_path
        )

        all_dfs.append(df)

    if len(all_dfs) == 0:
        raise ValueError("No datasets were loaded.")

    feature_db = pd.concat(all_dfs, ignore_index=True)

    metadata_cols = [
        "person",
        "dataset_path",
        "trial_idx",
        "label",
        "class_name"
    ]

    feature_cols = [
        c for c in feature_db.columns
        if c not in metadata_cols
    ]

    feature_db = feature_db[metadata_cols + feature_cols]

    feature_db.to_csv(FEATURE_DATABASE_PATH, index=False)

    print("\n========== FEATURE DATABASE SAVED ==========")
    print("Saved:", FEATURE_DATABASE_PATH)
    print("Shape:", feature_db.shape)
    print("People:", feature_db["person"].unique())
    print("Labels:")
    print(feature_db.groupby(["person", "class_name"]).size())

    return feature_db


def load_feature_database(path=FEATURE_DATABASE_PATH):
    print(f"\nLoading feature database: {path}")
    feature_db = pd.read_csv(path)

    print("Shape:", feature_db.shape)
    print("People:", feature_db["person"].unique())
    print("Labels:")
    print(feature_db.groupby(["person", "class_name"]).size())

    return feature_db


def get_feature_columns(feature_db):
    metadata_cols = [
        "person",
        "dataset_path",
        "trial_idx",
        "label",
        "class_name"
    ]

    return [c for c in feature_db.columns if c not in metadata_cols]


# ============================================================
# SIMILARITY METRICS
# ============================================================

def compare_feature_distributions(a, b):
    """
    Higher similarity_score = more similar.
    """

    a = np.asarray(a, dtype=float)
    b = np.asarray(b, dtype=float)

    a = a[np.isfinite(a)]
    b = b[np.isfinite(b)]

    if len(a) < 2 or len(b) < 2:
        return None

    mean_a = np.mean(a)
    mean_b = np.mean(b)

    std_a = np.std(a) + EPS
    std_b = np.std(b) + EPS

    pooled_std = np.sqrt((std_a ** 2 + std_b ** 2) / 2) + EPS

    abs_mean_diff = abs(mean_a - mean_b)
    normalized_mean_diff = abs_mean_diff / pooled_std

    median_diff = abs(np.median(a) - np.median(b)) / pooled_std

    wd = wasserstein_distance(a, b) / pooled_std

    ks_stat, ks_p = ks_2samp(a, b)

    similarity_score = 1.0 / (1.0 + normalized_mean_diff + wd + ks_stat)

    return {
        "person_a_mean": mean_a,
        "person_b_mean": mean_b,
        "person_a_std": std_a,
        "person_b_std": std_b,
        "abs_mean_diff": abs_mean_diff,
        "normalized_mean_diff": normalized_mean_diff,
        "normalized_median_diff": median_diff,
        "wasserstein_norm": wd,
        "ks_stat": ks_stat,
        "ks_p_value": ks_p,
        "similarity_score": similarity_score
    }


def compare_people_for_class(feature_db, person_a, person_b, class_label):
    feature_cols = get_feature_columns(feature_db)

    rows = []

    d1 = feature_db[
        (feature_db["person"] == person_a) &
        (feature_db["label"] == class_label)
    ]

    d2 = feature_db[
        (feature_db["person"] == person_b) &
        (feature_db["label"] == class_label)
    ]

    if len(d1) == 0 or len(d2) == 0:
        print(
            f"Skipping {person_a} vs {person_b}, class {class_label}. "
            f"Trials: {person_a}={len(d1)}, {person_b}={len(d2)}"
        )
        return pd.DataFrame()

    for feat in feature_cols:
        result = compare_feature_distributions(d1[feat], d2[feat])

        if result is None:
            continue

        result["feature"] = feat
        result["person_a"] = person_a
        result["person_b"] = person_b
        result["class_label"] = class_label
        result["class_name"] = CLASS_NAMES.get(class_label, str(class_label))

        rows.append(result)

    out = pd.DataFrame(rows)

    if len(out) == 0:
        return out

    out = out.sort_values("similarity_score", ascending=False).reset_index(drop=True)

    return out


def score_from_similarity_table(similarity_table):
    """
    Computes final person-to-person similarity score.

    Uses TOP_K_FEATURES_FOR_SCORE.
    If TOP_K_FEATURES_FOR_SCORE is None, uses all features.
    """

    if len(similarity_table) == 0:
        return np.nan

    scores = similarity_table["similarity_score"].values

    if TOP_K_FEATURES_FOR_SCORE is None:
        return safe(np.mean(scores))

    k = min(TOP_K_FEATURES_FOR_SCORE, len(scores))

    return safe(np.mean(scores[:k]))


def compute_pairwise_person_similarity(feature_db):
    people = sorted(feature_db["person"].unique())

    pair_rows = []
    detailed_tables = {}

    print("\n========== COMPUTING PAIRWISE PERSON SIMILARITY ==========")
    print("People:", people)
    print("Top K features used for final score:", TOP_K_FEATURES_FOR_SCORE)

    for person_a, person_b in tqdm(list(combinations(people, 2)), desc="Person pairs"):
        print(f"\nComparing {person_a} vs {person_b}")

        left_table = compare_people_for_class(
            feature_db=feature_db,
            person_a=person_a,
            person_b=person_b,
            class_label=LEFT_LABEL
        )

        right_table = compare_people_for_class(
            feature_db=feature_db,
            person_a=person_a,
            person_b=person_b,
            class_label=RIGHT_LABEL
        )

        left_score = score_from_similarity_table(left_table)
        right_score = score_from_similarity_table(right_table)

        pair_rows.append({
            "person_a": person_a,
            "person_b": person_b,
            "left_score": left_score,
            "right_score": right_score,
            "num_left_features": len(left_table),
            "num_right_features": len(right_table),
        })

        detailed_tables[(person_a, person_b, "left")] = left_table
        detailed_tables[(person_a, person_b, "right")] = right_table

        print(f"{person_a} vs {person_b}")
        print(f"LEFT score:  {left_score:.4f}")
        print(f"RIGHT score: {right_score:.4f}")

    pairwise_scores = pd.DataFrame(pair_rows)

    print("\n========== PAIRWISE SCORES ==========")
    print(pairwise_scores)

    return pairwise_scores, detailed_tables


def build_similarity_matrix(pairwise_scores, people, score_col):
    matrix = pd.DataFrame(
        np.eye(len(people)),
        index=people,
        columns=people,
        dtype=float
    )

    for _, row in pairwise_scores.iterrows():
        a = row["person_a"]
        b = row["person_b"]
        score = row[score_col]

        matrix.loc[a, b] = score
        matrix.loc[b, a] = score

    return matrix


def compute_person_average_similarity(similarity_matrix):
    rows = []

    people = list(similarity_matrix.index)

    for person in people:
        others = [p for p in people if p != person]
        scores = similarity_matrix.loc[person, others].values.astype(float)

        rows.append({
            "person": person,
            "average_similarity_to_others": np.nanmean(scores),
            "min_similarity_to_others": np.nanmin(scores),
            "max_similarity_to_others": np.nanmax(scores),
        })

    out = pd.DataFrame(rows)

    out = out.sort_values(
        "average_similarity_to_others",
        ascending=False
    ).reset_index(drop=True)

    return out


# ============================================================
# PLOTTING
# ============================================================

def plot_similarity_heatmap(similarity_matrix, title, save_path=None):
    fig, ax = plt.subplots(figsize=(8, 6))

    im = ax.imshow(similarity_matrix.values, vmin=0, vmax=1)

    ax.set_xticks(np.arange(len(similarity_matrix.columns)))
    ax.set_yticks(np.arange(len(similarity_matrix.index)))

    ax.set_xticklabels(similarity_matrix.columns, rotation=45, ha="right")
    ax.set_yticklabels(similarity_matrix.index)

    ax.set_title(title)

    for i in range(len(similarity_matrix.index)):
        for j in range(len(similarity_matrix.columns)):
            value = similarity_matrix.values[i, j]

            if np.isnan(value):
                text = "nan"
            else:
                text = f"{value:.2f}"

            ax.text(j, i, text, ha="center", va="center")

    fig.colorbar(im, ax=ax, label="Similarity score")

    plt.tight_layout()

    if SAVE_PLOTS and save_path is not None:
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        plt.savefig(save_path, dpi=200)
        print("Saved heatmap:", save_path)

    plt.show()


def plot_person_average_similarity(person_average_scores, title, save_path=None):
    fig, ax = plt.subplots(figsize=(8, 5))

    ax.bar(
        person_average_scores["person"],
        person_average_scores["average_similarity_to_others"]
    )

    ax.set_ylim(0, 1)
    ax.set_ylabel("Average similarity to others")
    ax.set_title(title)

    for i, value in enumerate(person_average_scores["average_similarity_to_others"]):
        ax.text(i, value, f"{value:.2f}", ha="center", va="bottom")

    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()

    if SAVE_PLOTS and save_path is not None:
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        plt.savefig(save_path, dpi=200)
        print("Saved bar plot:", save_path)

    plt.show()


# ============================================================
# SHARED FEATURE RANKING
# ============================================================

def rank_features_shared_across_all_people(feature_db, detailed_tables, class_name):
    """
    class_name:
    - "left"
    - "right"
    """

    if class_name not in ["left", "right"]:
        raise ValueError("class_name must be 'left' or 'right'")

    all_tables = []

    for key, table in detailed_tables.items():
        person_a, person_b, cls = key

        if cls != class_name:
            continue

        if len(table) == 0:
            continue

        tmp = table.copy()
        tmp["pair"] = f"{person_a} vs {person_b}"
        all_tables.append(tmp)

    if len(all_tables) == 0:
        return pd.DataFrame()

    all_pairwise = pd.concat(all_tables, ignore_index=True)

    shared = (
        all_pairwise
        .groupby("feature")
        .agg(
            mean_similarity=("similarity_score", "mean"),
            min_similarity=("similarity_score", "min"),
            max_similarity=("similarity_score", "max"),
            std_similarity=("similarity_score", "std"),
            mean_normalized_diff=("normalized_mean_diff", "mean"),
            mean_wasserstein=("wasserstein_norm", "mean"),
            mean_ks=("ks_stat", "mean"),
            num_pairs=("similarity_score", "count")
        )
        .reset_index()
    )

    shared["std_similarity"] = shared["std_similarity"].fillna(0.0)

    shared = shared.sort_values(
        ["mean_similarity", "min_similarity", "std_similarity"],
        ascending=[False, False, True]
    ).reset_index(drop=True)

    return shared


# ============================================================
# MAIN
# ============================================================

if REBUILD_FEATURE_DATABASE or not os.path.exists(FEATURE_DATABASE_PATH):
    feature_db = build_feature_database(DATASETS)
else:
    feature_db = load_feature_database(FEATURE_DATABASE_PATH)


print("\n========== AVAILABLE PEOPLE ==========")
print(feature_db["person"].unique())

print("\n========== DATABASE LABEL COUNTS ==========")
print(feature_db.groupby(["person", "class_name"]).size())


pairwise_scores, detailed_tables = compute_pairwise_person_similarity(feature_db)

people = sorted(feature_db["person"].unique())


# ============================================================
# CLASS-SPECIFIC MATRICES
# ============================================================

left_matrix = build_similarity_matrix(
    pairwise_scores=pairwise_scores,
    people=people,
    score_col="left_score"
)

right_matrix = build_similarity_matrix(
    pairwise_scores=pairwise_scores,
    people=people,
    score_col="right_score"
)

left_average_scores = compute_person_average_similarity(left_matrix)
right_average_scores = compute_person_average_similarity(right_matrix)


print("\n========== LEFT SIMILARITY MATRIX ==========")
print(left_matrix)

print("\n========== RIGHT SIMILARITY MATRIX ==========")
print(right_matrix)

print("\n========== LEFT PER-PERSON AVERAGE SIMILARITY ==========")
print(left_average_scores)

print("\n========== RIGHT PER-PERSON AVERAGE SIMILARITY ==========")
print(right_average_scores)


plot_similarity_heatmap(
    similarity_matrix=left_matrix,
    title=f"LEFT Class EEG Similarity Matrix | Top {TOP_K_FEATURES_FOR_SCORE} Features",
    save_path=LEFT_HEATMAP_PATH
)

plot_similarity_heatmap(
    similarity_matrix=right_matrix,
    title=f"RIGHT Class EEG Similarity Matrix | Top {TOP_K_FEATURES_FOR_SCORE} Features",
    save_path=RIGHT_HEATMAP_PATH
)

plot_person_average_similarity(
    person_average_scores=left_average_scores,
    title=f"LEFT Class Average Similarity | Top {TOP_K_FEATURES_FOR_SCORE} Features",
    save_path=LEFT_BARPLOT_PATH
)

plot_person_average_similarity(
    person_average_scores=right_average_scores,
    title=f"RIGHT Class Average Similarity | Top {TOP_K_FEATURES_FOR_SCORE} Features",
    save_path=RIGHT_BARPLOT_PATH
)


# ============================================================
# SHARED FEATURE TABLES
# ============================================================

shared_left_features = rank_features_shared_across_all_people(
    feature_db=feature_db,
    detailed_tables=detailed_tables,
    class_name="left"
)

shared_right_features = rank_features_shared_across_all_people(
    feature_db=feature_db,
    detailed_tables=detailed_tables,
    class_name="right"
)


print("\n========== TOP SHARED LEFT FEATURES ==========")
print(shared_left_features.head(50))

print("\n========== TOP SHARED RIGHT FEATURES ==========")
print(shared_right_features.head(50))


print("\n========== FINAL RESULT ==========")

print("\nPairwise person similarity:")
print(pairwise_scores)

print("\nLEFT similarity matrix:")
print(left_matrix)

print("\nRIGHT similarity matrix:")
print(right_matrix)

print("\nLEFT average similarity:")
print(left_average_scores)

print("\nRIGHT average similarity:")
print(right_average_scores)

print("\nOnly feature database saved as:")
print(FEATURE_DATABASE_PATH)

if SAVE_PLOTS:
    print("\nPlots saved as:")
    print(LEFT_HEATMAP_PATH)
    print(RIGHT_HEATMAP_PATH)
    print(LEFT_BARPLOT_PATH)
    print(RIGHT_BARPLOT_PATH)
# Out:
# ========== BUILDING FEATURE DATABASE ==========
#
# Loading Arnav: Datasets/Main.npz
#
# Raw loaded: Datasets/Main.npz
# Before bad-channel deletion: (480, 8, 1750)
# After bad-channel deletion: (480, 2, 1750)
# Arnav labels: (array([1, 2]), array([240, 240]))
#
# ========== EXTRACTING FEATURES: Arnav ==========
# Dataset path: Datasets/Main.npz
# X shape: (480, 2, 1750)
# Labels: (array([1, 2]), array([240, 240]))
# USE_SLOW_FEATURES: False
# USE_CROSS_CHANNEL_BAND_FEATURES: True
# Arnav trials: 100%|██████████| 480/480 [00:26<00:00, 17.89it/s]
# Done: Arnav
# Feature table shape: (480, 179)
#
# Loading Fauzaan: Datasets/Main1.npz
#
# Raw loaded: Datasets/Main1.npz
# Before bad-channel deletion: (60, 8, 1750)
# After bad-channel deletion: (60, 2, 1750)
# Fauzaan labels: (array([1, 2], dtype=int32), array([30, 30]))
#
# ========== EXTRACTING FEATURES: Fauzaan ==========
# Dataset path: Datasets/Main1.npz
# X shape: (60, 2, 1750)
# Labels: (array([1, 2], dtype=int32), array([30, 30]))
# USE_SLOW_FEATURES: False
# USE_CROSS_CHANNEL_BAND_FEATURES: True
# Fauzaan trials: 100%|██████████| 60/60 [00:03<00:00, 17.51it/s]
# Done: Fauzaan
# Feature table shape: (60, 179)
#
# Loading Devin: Datasets/Main2.npz
#
# Raw loaded: Datasets/Main2.npz
# Before bad-channel deletion: (60, 8, 1750)
# After bad-channel deletion: (60, 2, 1750)
# Devin labels: (array([1, 2]), array([30, 30]))
#
# ========== EXTRACTING FEATURES: Devin ==========
# Dataset path: Datasets/Main2.npz
# X shape: (60, 2, 1750)
# Labels: (array([1, 2]), array([30, 30]))
# USE_SLOW_FEATURES: False
# USE_CROSS_CHANNEL_BAND_FEATURES: True
# Devin trials: 100%|██████████| 60/60 [00:03<00:00, 19.18it/s]
# Done: Devin
# Feature table shape: (60, 179)
#
# Loading Erim: Datasets/Main3.npz
#
# Raw loaded: Datasets/Main3.npz
# Before bad-channel deletion: (60, 8, 1750)
# After bad-channel deletion: (60, 2, 1750)
# Erim labels: (array([1, 2]), array([30, 30]))
#
# ========== EXTRACTING FEATURES: Erim ==========
# Dataset path: Datasets/Main3.npz
# X shape: (60, 2, 1750)
# Labels: (array([1, 2]), array([30, 30]))
# USE_SLOW_FEATURES: False
# USE_CROSS_CHANNEL_BAND_FEATURES: True
# Erim trials: 100%|██████████| 60/60 [00:03<00:00, 18.75it/s]
# Done: Erim
# Feature table shape: (60, 179)
#
# ========== FEATURE DATABASE SAVED ==========
# Saved: Datasets/eeg_feature_database.csv
# Shape: (660, 179)
# People: ['Arnav' 'Fauzaan' 'Devin' 'Erim']
# Labels:
# person   class_name
# Arnav    left          240
#          right         240
# Devin    left           30
#          right          30
# Erim     left           30
#          right          30
# Fauzaan  left           30
#          right          30
# dtype: int64
#
# ========== AVAILABLE PEOPLE ==========
# ['Arnav' 'Fauzaan' 'Devin' 'Erim']
#
# ========== DATABASE LABEL COUNTS ==========
# person   class_name
# Arnav    left          240
#          right         240
# Devin    left           30
#          right          30
# Erim     left           30
#          right          30
# Fauzaan  left           30
#          right          30
# dtype: int64
#
# ========== COMPUTING PAIRWISE PERSON SIMILARITY ==========
# People: ['Arnav', 'Devin', 'Erim', 'Fauzaan']
# Top K features used for final score: 75
# Person pairs:   0%|          | 0/6 [00:00<?, ?it/s]
# Comparing Arnav vs Devin
# Person pairs:  17%|█▋        | 1/6 [00:00<00:01,  3.08it/s]
# Arnav vs Devin
# LEFT score:  0.6174
# RIGHT score: 0.5982
#
# Comparing Arnav vs Erim
# Person pairs:  33%|███▎      | 2/6 [00:00<00:01,  3.04it/s]
# Arnav vs Erim
# LEFT score:  0.6151
# RIGHT score: 0.5966
#
# Comparing Arnav vs Fauzaan
# Person pairs:  50%|█████     | 3/6 [00:00<00:00,  3.15it/s]
# Arnav vs Fauzaan
# LEFT score:  0.6436
# RIGHT score: 0.6130
#
# Comparing Devin vs Erim
# c:\Stored Data\BrainDance\venv\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   res = hypotest_fun_out(*samples, **kwds)
# Person pairs:  67%|██████▋   | 4/6 [00:01<00:00,  3.24it/s]
# Devin vs Erim
# LEFT score:  0.5644
# RIGHT score: 0.5428
#
# Comparing Devin vs Fauzaan
# Person pairs:  83%|████████▎ | 5/6 [00:01<00:00,  3.41it/s]
# Devin vs Fauzaan
# LEFT score:  0.5372
# RIGHT score: 0.5053
#
# Comparing Erim vs Fauzaan
# Person pairs: 100%|██████████| 6/6 [00:01<00:00,  3.35it/s]
# Erim vs Fauzaan
# LEFT score:  0.5418
# RIGHT score: 0.5351
#
# ========== PAIRWISE SCORES ==========
#   person_a person_b  left_score  right_score  num_left_features  \
# 0    Arnav    Devin    0.617357     0.598154                174
# 1    Arnav     Erim    0.615133     0.596551                174
# 2    Arnav  Fauzaan    0.643636     0.613022                174
# 3    Devin     Erim    0.564353     0.542829                174
# 4    Devin  Fauzaan    0.537186     0.505343                174
# 5     Erim  Fauzaan    0.541780     0.535096                174
#
#    num_right_features
# 0                 174
# 1                 174
# 2                 174
# 3                 174
# 4                 174
# 5                 174
#
# ========== LEFT SIMILARITY MATRIX ==========
#             Arnav     Devin      Erim   Fauzaan
# Arnav    1.000000  0.617357  0.615133  0.643636
# Devin    0.617357  1.000000  0.564353  0.537186
# Erim     0.615133  0.564353  1.000000  0.541780
# Fauzaan  0.643636  0.537186  0.541780  1.000000
#
# ========== RIGHT SIMILARITY MATRIX ==========
#             Arnav     Devin      Erim   Fauzaan
# Arnav    1.000000  0.598154  0.596551  0.613022
# Devin    0.598154  1.000000  0.542829  0.505343
# Erim     0.596551  0.542829  1.000000  0.535096
# Fauzaan  0.613022  0.505343  0.535096  1.000000
#
# ========== LEFT PER-PERSON AVERAGE SIMILARITY ==========
#     person  average_similarity_to_others  min_similarity_to_others  \
# 0    Arnav                      0.625375                  0.615133
# 1  Fauzaan                      0.574200                  0.537186
# 2     Erim                      0.573755                  0.541780
# 3    Devin                      0.572965                  0.537186
#
#    max_similarity_to_others
# 0                  0.643636
# 1                  0.643636
# 2                  0.615133
# 3                  0.617357
#
# ========== RIGHT PER-PERSON AVERAGE SIMILARITY ==========
#     person  average_similarity_to_others  min_similarity_to_others  \
# 0    Arnav                      0.602576                  0.596551
# 1     Erim                      0.558159                  0.535096
# 2  Fauzaan                      0.551154                  0.505343
# 3    Devin                      0.548776                  0.505343
#
#    max_similarity_to_others
# 0                  0.613022
# 1                  0.596551
# 2                  0.613022
# 3                  0.598154
# ========== TOP SHARED LEFT FEATURES ==========
#                               feature  mean_similarity  min_similarity  \
# 0                ch1_spectral_edge_95         0.833430        0.666859
# 1                ch0_spectral_edge_95         0.814650        0.629301
# 2                   ch1_dominant_freq         0.783725        0.567451
# 3                ch0_spectral_edge_90         0.750738        0.501476
# 4                   ch0_dominant_freq         0.707614        0.415229
# 5                            ch0_skew         0.686162        0.629165
# 6                            ch1_skew         0.655100        0.542487
# 7                          ch0_median         0.636995        0.511530
# 8                        ch0_kurtosis         0.620121        0.514586
# 9                          ch1_median         0.613323        0.433887
# 10       ch0_ch1_theta_power_abs_diff         0.612692        0.460024
# 11                    ch0_theta_power         0.612043        0.529569
# 12           ch0_ch1_theta_power_diff         0.606325        0.391045
# 13      ch0_ch1_high_beta_power_ratio         0.602356        0.497463
# 14       ch0_ch1_delta_power_abs_diff         0.600190        0.560876
# 15              ch1_delta_theta_ratio         0.598772        0.498705
# 16                           ch0_mean         0.597194        0.532517
# 17  ch0_ch1_high_beta_log_power_ratio         0.596002        0.466521
# 18                    ch1_delta_power         0.583692        0.397933
# 19    ch0_ch1_low_beta_power_abs_diff         0.580457        0.381723
# 20                    ch1_theta_power         0.575563        0.466389
# 21             ch0_ch1_smr_power_diff         0.574989        0.440734
# 22        ch0_ch1_low_beta_power_diff         0.570727        0.404662
# 23           ch0_ch1_delta_power_diff         0.568592        0.370445
# 24               ch1_spectral_edge_90         0.557149        0.284190
# 25                            ch0_min         0.556063        0.486288
# 26                    ch0_delta_power         0.553807        0.303082
# 27       ch0_ch1_high_beta_power_diff         0.553278        0.434032
# 28                           ch1_mean         0.552686        0.478082
# 29            ch0_ch1_beta_power_diff         0.552034        0.397254
# 30                            ch0_var         0.545702        0.410446
# 31                ch0_hjorth_activity         0.545702        0.410446
# 32                         ch0_energy         0.545363        0.409968
# 33          ch0_ch1_delta_power_ratio         0.541982        0.435618
# 34        ch0_ch1_beta_power_abs_diff         0.528633        0.370004
# 35         ch0_ch1_smr_power_abs_diff         0.528148        0.253055
# 36                       ch1_kurtosis         0.526817        0.387894
# 37       ch0_ch1_beta_log_power_ratio         0.515451        0.433661
# 38                 ch1_low_beta_power         0.514957        0.383562
# 39        ch0_ch1_smr_log_power_ratio         0.514125        0.397593
# 40                       ch0_mean_abs         0.511249        0.415785
# 41                            ch0_std         0.510892        0.420736
# 42                            ch0_rms         0.510520        0.420079
# 43                ch0_theta_log_power         0.509493        0.400981
# 44                            ch0_iqr         0.505334        0.411288
# 45          ch0_ch1_theta_power_ratio         0.499558        0.334146
# 46      ch0_ch1_theta_log_power_ratio         0.495947        0.360569
# 47   ch0_ch1_high_beta_power_abs_diff         0.495475        0.384565
# 48                  ch0_ch1_theta_cov         0.494113        0.260635
# 49                  ch0_ch1_delta_cov         0.490440        0.243172
#
#     max_similarity  std_similarity  mean_normalized_diff  mean_wasserstein  \
# 0         1.000000        0.182469              0.114475          0.114475
# 1         1.000000        0.203040              0.101433          0.101433
# 2         1.000000        0.236917              0.175983          0.175983
# 3         1.000000        0.273053              0.176654          0.176654
# 4         1.000000        0.320292              0.311453          0.311453
# 5         0.763672        0.053363              0.103066          0.211578
# 6         0.836490        0.112753              0.166875          0.250492
# 7         0.697638        0.077765              0.122675          0.248959
# 8         0.712301        0.077857              0.148003          0.284654
# 9         0.761798        0.125894              0.180429          0.299737
# 10        0.745786        0.117670              0.228827          0.263918
# 11        0.689526        0.063202              0.158117          0.226279
# 12        0.767567        0.152880              0.159359          0.338364
# 13        0.754998        0.091165              0.094148          0.372636
# 14        0.668014        0.037683              0.165028          0.264676
# 15        0.800871        0.107635              0.236886          0.282296
# 16        0.658980        0.050220              0.125230          0.375223
# 17        0.740377        0.108803              0.139136          0.362929
# 18        0.675533        0.109000              0.207439          0.262898
# 19        0.715366        0.139645              0.291513          0.310490
# 20        0.689328        0.085957              0.214631          0.258612
# 21        0.748663        0.124328              0.068994          0.381862
# 22        0.679827        0.104715              0.100665          0.371538
# 23        0.689528        0.127352              0.248899          0.346286
# 24        1.000000        0.264582              0.485492          0.500517
# 25        0.692772        0.077826              0.189500          0.399429
# 26        0.745335        0.162534              0.295748          0.321639
# 27        0.631391        0.084108              0.227641          0.340460
# 28        0.683011        0.072515              0.154699          0.452018
# 29        0.659339        0.112423              0.196413          0.366832
# 30        0.639409        0.092965              0.138669          0.312574
# 31        0.639409        0.092965              0.138669          0.312574
# 32        0.639403        0.093118              0.139772          0.312824
# 33        0.682393        0.106329              0.215952          0.424221
# 34        0.758225        0.139200              0.325858          0.335620
# 35        0.756952        0.185488              0.372872          0.411779
# 36        0.616583        0.093118              0.276206          0.427562
# 37        0.668700        0.083645              0.142827          0.510475
# 38        0.624050        0.106387              0.287269          0.318641
# 39        0.649343        0.093981              0.125681          0.545131
# 40        0.566035        0.060803              0.109103          0.429364
# 41        0.556662        0.053680              0.123874          0.422811
# 42        0.556690        0.053595              0.125097          0.423026
# 43        0.613089        0.096861              0.329312          0.430844
# 44        0.573062        0.067815              0.114431          0.444057
# 45        0.624137        0.134572              0.341806          0.515680
# 46        0.655920        0.111321              0.330748          0.494036
# 47        0.710139        0.114973              0.332175          0.346970
# 48        0.683459        0.196303              0.490462          0.515100
# 49        0.666610        0.195587              0.495650          0.506026
#
#      mean_ks  num_pairs
# 0   0.020833          6
# 1   0.091667          6
# 2   0.029167          6
# 3   0.143750          6
# 4   0.081250          6
# 5   0.150000          6
# 6   0.145139          6
# 7   0.220139          6
# 8   0.202083          6
# 9   0.214583          6
# 10  0.196528          6
# 11  0.264583          6
# 12  0.255556          6
# 13  0.223611          6
# 14  0.241667          6
# 15  0.190278          6
# 16  0.184028          6
# 17  0.223611          6
# 18  0.304861          6
# 19  0.216667          6
# 20  0.297222          6
# 21  0.358333          6
# 22  0.337500          6
# 23  0.252083          6
# 24  0.200000          6
# 25  0.236111          6
# 26  0.361111          6
# 27  0.278472          6
# 28  0.226389          6
# 29  0.318750          6
# 30  0.430556          6
# 31  0.430556          6
# 32  0.430556          6
# 33  0.264583          6
# 34  0.336111          6
# 35  0.375694          6
# 36  0.250000          6
# 37  0.325000          6
# 38  0.415278          6
# 39  0.329861          6
# 40  0.443056          6
# 41  0.430556          6
# 42  0.430556          6
# 43  0.264583          6
# 44  0.452778          6
# 45  0.278472          6
# 46  0.278472          6
# 47  0.417361          6
# 48  0.379861          6
# 49  0.432639          6
#
# ========== TOP SHARED RIGHT FEATURES ==========
#                               feature  mean_similarity  min_similarity  \
# 0                ch1_spectral_edge_95         0.805945        0.611890
# 1                ch0_spectral_edge_95         0.800690        0.601379
# 2                   ch1_dominant_freq         0.774418        0.548836
# 3                   ch0_dominant_freq         0.709640        0.419280
# 4                          ch0_median         0.690865        0.634307
# 5                        ch0_kurtosis         0.641381        0.564213
# 6        ch0_ch1_theta_power_abs_diff         0.622087        0.421237
# 7                ch0_spectral_edge_90         0.619488        0.474356
# 8                            ch0_skew         0.618567        0.537239
# 9     ch0_ch1_low_beta_power_abs_diff         0.606393        0.431476
# 10                           ch0_mean         0.602476        0.552350
# 11                            ch0_max         0.597009        0.539602
# 12                         ch1_median         0.596582        0.456226
# 13        ch0_ch1_low_beta_power_diff         0.594142        0.467394
# 14                   ch0_hist_entropy         0.587998        0.545334
# 15           ch0_ch1_theta_power_diff         0.586409        0.370212
# 16            ch0_ch1_beta_power_diff         0.584419        0.404862
# 17        ch0_ch1_beta_power_abs_diff         0.581807        0.361264
# 18                           ch1_skew         0.575222        0.445758
# 19                            ch0_min         0.573519        0.476982
# 20           ch0_ch1_delta_power_diff         0.569736        0.367561
# 21       ch0_ch1_delta_power_abs_diff         0.562725        0.330715
# 22                    ch1_theta_power         0.562352        0.459536
# 23                            ch0_ptp         0.560609        0.448196
# 24                    ch1_delta_power         0.551735        0.445019
# 25                    ch0_theta_power         0.545966        0.408977
# 26         ch0_ch1_smr_power_abs_diff         0.542699        0.320256
# 27          ch0_ch1_delta_power_ratio         0.534651        0.431737
# 28       ch0_ch1_high_beta_power_diff         0.534146        0.378542
# 29             ch0_ch1_smr_power_diff         0.523712        0.360520
# 30                           ch1_mean         0.520044        0.402746
# 31                    ch0_delta_power         0.517863        0.350182
# 32   ch0_ch1_high_beta_power_abs_diff         0.510474        0.321480
# 33      ch0_ch1_high_beta_power_ratio         0.508186        0.388810
# 34  ch0_ch1_high_beta_log_power_ratio         0.501859        0.412389
# 35                 ch1_low_beta_power         0.496079        0.399440
# 36       ch0_ch1_beta_log_power_ratio         0.495861        0.414389
# 37                       ch1_kurtosis         0.495044        0.355572
# 38      ch0_ch1_theta_log_power_ratio         0.487944        0.355895
# 39      ch0_ch1_delta_log_power_ratio         0.487507        0.377595
# 40                ch1_theta_log_power         0.482158        0.384562
# 41               ch1_spectral_edge_90         0.480618        0.243166
# 42       ch0_ch1_gamma_low_power_diff         0.478900        0.291104
# 43              ch1_delta_theta_ratio         0.478234        0.373334
# 44          ch0_ch1_theta_power_ratio         0.471887        0.330716
# 45                            ch1_min         0.469857        0.325623
# 46                         ch0_energy         0.468570        0.307278
# 47                            ch0_var         0.467961        0.307539
# 48                ch0_hjorth_activity         0.467961        0.307539
# 49           ch0_ch1_beta_power_ratio         0.467034        0.354874
#
#     max_similarity  std_similarity  mean_normalized_diff  mean_wasserstein  \
# 0         1.000000        0.212576              0.141903          0.141903
# 1         1.000000        0.218334              0.125086          0.125086
# 2         1.000000        0.247113              0.188843          0.188843
# 3         1.000000        0.318074              0.306677          0.306677
# 4         0.745233        0.039793              0.054671          0.219720
# 5         0.775689        0.076830              0.133867          0.256604
# 6         0.773539        0.135616              0.153321          0.272423
# 7         1.000000        0.202972              0.294747          0.294747
# 8         0.721792        0.069492              0.157726          0.266951
# 9         0.712527        0.125156              0.228629          0.259533
# 10        0.706031        0.055178              0.160479          0.331527
# 11        0.638095        0.040232              0.199666          0.266616
# 12        0.721656        0.124132              0.167570          0.337476
# 13        0.691337        0.101649              0.106519          0.305631
# 14        0.649205        0.035206              0.171213          0.327444
# 15        0.739679        0.160328              0.272070          0.304090
# 16        0.742917        0.140531              0.170696          0.335825
# 17        0.741574        0.170076              0.276733          0.329240
# 18        0.671350        0.092471              0.214782          0.357386
# 19        0.694575        0.077397              0.212916          0.311094
# 20        0.730080        0.161141              0.284572          0.339535
# 21        0.750525        0.175770              0.326584          0.347668
# 22        0.637102        0.074894              0.221197          0.291126
# 23        0.606380        0.058939              0.191469          0.329491
# 24        0.594369        0.057670              0.219908          0.253862
# 25        0.608890        0.073072              0.208321          0.326403
# 26        0.685568        0.141112              0.276779          0.325095
# 27        0.612710        0.076798              0.172296          0.481312
# 28        0.714377        0.160904              0.290032          0.398749
# 29        0.657282        0.126748              0.218814          0.354356
# 30        0.660160        0.092380              0.235892          0.478403
# 31        0.635598        0.114729              0.325183          0.337228
# 32        0.706769        0.162060              0.350432          0.396307
# 33        0.770519        0.138710              0.288930          0.513070
# 34        0.760167        0.129836              0.304656          0.505081
# 35        0.551993        0.060532              0.275430          0.333786
# 36        0.696919        0.102748              0.182797          0.565696
# 37        0.669090        0.113932              0.319366          0.483719
# 38        0.604016        0.112312              0.360119          0.482171
# 39        0.577618        0.069860              0.319585          0.518251
# 40        0.648603        0.092648              0.361744          0.476776
# 41        0.641618        0.179327              0.588138          0.607931
# 42        0.650640        0.160037              0.362331          0.478358
# 43        0.586147        0.070954              0.358901          0.472015
# 44        0.618967        0.136613              0.420937          0.551414
# 45        0.593334        0.093461              0.381474          0.453544
# 46        0.611719        0.119860              0.340385          0.496833
# 47        0.611719        0.120380              0.339533          0.496230
# 48        0.611719        0.120380              0.339533          0.496230
# 49        0.739725        0.146852              0.328713          0.628606
#
#      mean_ks  num_pairs
# 0   0.033333          6
# 1   0.081250          6
# 2   0.033333          6
# 3   0.079167          6
# 4   0.177083          6
# 5   0.186111          6
# 6   0.254167          6
# 7   0.143056          6
# 8   0.209028          6
# 9   0.231250          6
# 10  0.178472          6
# 11  0.215278          6
# 12  0.235417          6
# 13  0.316667          6
# 14  0.206944          6
# 15  0.261806          6
# 16  0.302778          6
# 17  0.270139          6
# 18  0.207639          6
# 19  0.245833          6
# 20  0.264583          6
# 21  0.293750          6
# 22  0.293750          6
# 23  0.281944          6
# 24  0.357639          6
# 25  0.329861          6
# 26  0.372917          6
# 27  0.251389          6
# 28  0.334722          6
# 29  0.440278          6
# 30  0.259722          6
# 31  0.360417          6
# 32  0.404167          6
# 33  0.268056          6
# 34  0.268056          6
# 35  0.434028          6
# 36  0.327083          6
# 37  0.306944          6
# 38  0.304167          6
# 39  0.251389          6
# 40  0.293750          6
# 41  0.243750          6
# 42  0.489583          6
# 43  0.300000          6
# 44  0.304167          6
# 45  0.372917          6
# 46  0.427778          6
# 47  0.433333          6
# 48  0.433333          6
# 49  0.327083          6
#
# ========== FINAL RESULT ==========
#
# Pairwise person similarity:
#   person_a person_b  left_score  right_score  num_left_features  \
# 0    Arnav    Devin    0.617357     0.598154                174
# 1    Arnav     Erim    0.615133     0.596551                174
# 2    Arnav  Fauzaan    0.643636     0.613022                174
# 3    Devin     Erim    0.564353     0.542829                174
# 4    Devin  Fauzaan    0.537186     0.505343                174
# 5     Erim  Fauzaan    0.541780     0.535096                174
#
#    num_right_features
# 0                 174
# 1                 174
# 2                 174
# 3                 174
# 4                 174
# 5                 174
#
# LEFT similarity matrix:
#             Arnav     Devin      Erim   Fauzaan
# Arnav    1.000000  0.617357  0.615133  0.643636
# Devin    0.617357  1.000000  0.564353  0.537186
# Erim     0.615133  0.564353  1.000000  0.541780
# Fauzaan  0.643636  0.537186  0.541780  1.000000
#
# RIGHT similarity matrix:
#             Arnav     Devin      Erim   Fauzaan
# Arnav    1.000000  0.598154  0.596551  0.613022
# Devin    0.598154  1.000000  0.542829  0.505343
# Erim     0.596551  0.542829  1.000000  0.535096
# Fauzaan  0.613022  0.505343  0.535096  1.000000
#
# LEFT average similarity:
#     person  average_similarity_to_others  min_similarity_to_others  \
# 0    Arnav                      0.625375                  0.615133
# 1  Fauzaan                      0.574200                  0.537186
# 2     Erim                      0.573755                  0.541780
# 3    Devin                      0.572965                  0.537186
#
#    max_similarity_to_others
# 0                  0.643636
# 1                  0.643636
# 2                  0.615133
# 3                  0.617357
#
# RIGHT average similarity:
#     person  average_similarity_to_others  min_similarity_to_others  \
# 0    Arnav                      0.602576                  0.596551
# 1     Erim                      0.558159                  0.535096
# 2  Fauzaan                      0.551154                  0.505343
# 3    Devin                      0.548776                  0.505343
#
#    max_similarity_to_others
# 0                  0.613022
# 1                  0.596551
# 2                  0.613022
# 3                  0.598154
#
# Only feature database saved as:
# Datasets/eeg_feature_database.csv
